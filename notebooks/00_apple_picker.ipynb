# %%
import sys
sys.path.insert(0, '../src')

import aspire
from aspire.apple.apple import Apple

# %%
apple_picker = Apple()
filename = '../tests/saved_test_data/mrc_files/falcon_2012_06_12-14_33_35_0.mrc'

# %%
centers = apple_picker.process_micrograph(filename, show_progress=False)
# Out:
# 2019/06/17 14:39:43 Reading MRC file
# 2019/06/17 14:39:44 Computing scores for query images
# 2019/06/17 14:40:13 Running svm with tau1=710, tau2=7100
# 2019/06/17 14:40:19 Discarding suspected artifacts
# 2019/06/17 14:40:25 Getting particle centers

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import mrcfile
with mrcfile.open(filename, mode='r') as mrc:
    micro_img = mrc.data

# %%
micro_img.shape
# Out:
# (4096, 4096)

# %%
apple_picker2.tau2
# Out:
# 7100

# %%
centers.shape
# Out:
# (504, 2)

# %%
plt.title('A simple chirp')
plt.imshow(micro_img)
